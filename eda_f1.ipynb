# %%
# Import pandas
import pandas as pd

# %% [markdown]
# **Day 1**
# Task 1: Load the data. Print the first 5 rows of results.csv, drivers.csv, and races.csv.

# %%
# load data results
results_df = pd.read_csv("data/results.csv")
# load data drivers
drivers_df = pd.read_csv("data/drivers.csv")
# load data races
races_df = pd.read_csv("data/races.csv")

# %%
# inspect head of results
results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
# inspect info of results
results_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26080 entries, 0 to 26079
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26080 non-null  int64
#  1   raceId           26080 non-null  int64
#  2   driverId         26080 non-null  int64
#  3   constructorId    26080 non-null  int64
#  4   number           26080 non-null  str
#  5   grid             26080 non-null  int64
#  6   position         26080 non-null  str
#  7   positionText     26080 non-null  str
#  8   positionOrder    26080 non-null  int64
#  9   points           26080 non-null  float64
#  10  laps             26080 non-null  int64
#  11  time             26080 non-null  str
#  12  milliseconds     26080 non-null  str
#  13  fastestLap       26080 non-null  str
#  14  rank             26080 non-null  str
#  15  fastestLapTime   26080 non-null  str
#  16  fastestLapSpeed  26080 non-null  str
# ...

# %%
# inspect head of drivers
drivers_df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
# inspect info of drivers
drivers_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     857 non-null    int64
#  1   driverRef    857 non-null    str
#  2   number       857 non-null    str
#  3   code         857 non-null    str
#  4   forename     857 non-null    str
#  5   surname      857 non-null    str
#  6   dob          857 non-null    str
#  7   nationality  857 non-null    str
#  8   url          857 non-null    str
# dtypes: int64(1), str(8)
# memory usage: 60.4 KB

# %%
# inspect head of races
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
# inspect info of races
races_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   raceId       1101 non-null   int64
#  1   year         1101 non-null   int64
#  2   round        1101 non-null   int64
#  3   circuitId    1101 non-null   int64
#  4   name         1101 non-null   str
#  5   date         1101 non-null   str
#  6   time         1101 non-null   str
#  7   url          1101 non-null   str
#  8   fp1_date     1101 non-null   str
#  9   fp1_time     1101 non-null   str
#  10  fp2_date     1101 non-null   str
#  11  fp2_time     1101 non-null   str
#  12  fp3_date     1101 non-null   str
#  13  fp3_time     1101 non-null   str
#  14  quali_date   1101 non-null   str
#  15  quali_time   1101 non-null   str
#  16  sprint_date  1101 non-null   str
#  17  sprint_time  1101 non-null   str
# dtypes: int64(4), str(14)
# memory usage: 155.0 KB

# %% [markdown]
# Task 2: Find the top 10 drivers by total career points. Plot it as a bar chart.

# %%
# merge results with drivers
resultsxdrivers_df = results_df.merge(drivers_df, on= "driverId", how = "left", validate = "m:1", indicator = True, suffixes = ("_res", "_dri"))
# check if it worked
resultsxdrivers_df.head(50)
# Out:
#     resultId  raceId  driverId  constructorId number_res  grid position  \
# 0          1      18         1              1         22     1        1
# 1          2      18         2              2          3     5        2
# 2          3      18         3              3          7     7        3
# 3          4      18         4              4          5    11        4
# 4          5      18         5              1         23     3        5
# 5          6      18         6              3          8    13        6
# 6          7      18         7              5         14    17        7
# 7          8      18         8              6          1    15        8
# 8          9      18         9              2          4     2       \N
# 9         10      18        10              7         12    18       \N
# 10        11      18        11              8         18    19       \N
# 11        12      18        12              4          6    20       \N
# ...

# %%
# LESSON: merging dataframes
#
# STEP 1 — know your key relationship before merging
#
#   ask: "can this key appear multiple times in each df?"
#   run: print(df["key_col"].duplicated().sum())
#         0 = "1" side,  >0 = "m" side
#
#   "1:1" → one row per key on both sides
#   "m:1" → many rows on left, one row on right  (most common)
#   "1:m" → one row on left, many rows on right
#   "m:m" → many on both — usually a mistake, avoid
#
# STEP 2 — always use validate + indicator=True
#
#   merged_df = left_df.merge(
#       right_df,
#       on="key_col",
#       how="left",        # be intentional: inner/left/right/outer
#       validate="m:1",    # states your assumption, crashes if wrong
#       indicator=True,    # adds _merge column to check match quality
#   )
#
# STEP 3 — inspect the _merge column immediately after
#
#   print(merged_df["_merge"].value_counts())
#
#   "both"       → matched in both dfs        (expected)
#   "left_only"  → no match found in right df (investigate)
#   "right_only" → no match found in left df  (investigate)
#
#   filter unmatched rows:
#   merged_df[merged_df["_merge"] == "left_only"]
#
# STEP 4 — drop _merge when done
#
#   merged_df = merged_df.drop(columns="_merge")
#
# WHAT TO EXPECT FROM _merge BY JOIN TYPE
#
#   how="inner"  → "both" only
#   how="left"   → "both" + "left_only" expected
#                  "right_only" should NEVER appear — if it does, something is wrong
#   how="right"  → "both" + "right_only" expected
#                  "left_only" should NEVER appear — if it does, something is wrong
#   how="outer"  → all three are possible

# %%
# group by drivers and sum descending
drivers_ranked = resultsxdrivers_df.groupby(["driverId", "forename", "surname"])["points"].sum().sort_values(ascending=False).reset_index()

# %%
# check drivers_ranked
drivers_ranked.head(10)
# Out:
#    driverId   forename     surname  points
# 0         1      Lewis    Hamilton  4540.5
# 1        20  Sebastian      Vettel  3098.0
# 2       830        Max  Verstappen  2275.5
# 3         4   Fernando      Alonso  2203.0
# 4         8       Kimi   Räikkönen  1873.0
# 5       822   Valtteri      Bottas  1783.0
# 6         3       Nico     Rosberg  1594.5
# 7        30    Michael  Schumacher  1566.0
# 8       815     Sergio       Pérez  1361.0
# 9       817     Daniel   Ricciardo  1307.0

# %%
# add column that combines first and last name
drivers_ranked["name full"] = drivers_ranked.forename + " " + drivers_ranked.surname

# %%
# check drivers_ranked
drivers_ranked
# Out:
#      driverId   forename     surname  points         name full
# 0           1      Lewis    Hamilton  4540.5    Lewis Hamilton
# 1          20  Sebastian      Vettel  3098.0  Sebastian Vettel
# 2         830        Max  Verstappen  2275.5    Max Verstappen
# 3           4   Fernando      Alonso  2203.0   Fernando Alonso
# 4           8       Kimi   Räikkönen  1873.0    Kimi Räikkönen
# ..        ...        ...         ...     ...               ...
# 852       494      Lloyd        Ruby     0.0        Lloyd Ruby
# 853       493      Peter        Ryan     0.0        Peter Ryan
# 854       492     Menato       Boffa     0.0      Menato Boffa
# 855       491    Alfonso      Thiele     0.0    Alfonso Thiele
# 856       858      Logan    Sargeant     0.0    Logan Sargeant
#
# [857 rows x 5 columns]

# %%
# drop forename and surname
drivers_ranked = drivers_ranked.drop(columns = ["surname", "forename", "driverId"])

# %%
# check drivers_ranked again
drivers_ranked
# Out:
#      points         name full
# 0    4540.5    Lewis Hamilton
# 1    3098.0  Sebastian Vettel
# 2    2275.5    Max Verstappen
# 3    2203.0   Fernando Alonso
# 4    1873.0    Kimi Räikkönen
# ..      ...               ...
# 852     0.0        Lloyd Ruby
# 853     0.0        Peter Ryan
# 854     0.0      Menato Boffa
# 855     0.0    Alfonso Thiele
# 856     0.0    Logan Sargeant
#
# [857 rows x 2 columns]

# %%
# fix driver names in driverRef column
#drivers_ranked_top10["driverRef"] = drivers_ranked_top10["driverRef"].replace(["hamilton", "vettel", "max_verstappen", "alonso", "raikkonen", "bottas", "rosberg", "michael_schumacher", "perez", "ricciardo"], ["L. Hamilton", "S. Vettel", "M. Verstappen", "F. Alonso", "K. Raikkonen", "V. Bottas", "N. Rosberg", "M. Schumacher", "S. Perez", "D. Ricciardo"])

# Bug Fix
# I originally wanted to change the names in column driverRef by using the following code: 
# drivers_ranked_top10 = drivers_ranked_top10["driverRef"].replace(["hamilton", "vettel", "max_verstappen", "alonso", "raikkonen", "bottas", "rosberg", "michael_schumacher", "perez", "ricciardo"], ["L. Hamilton", "S. Vettel", "M. Verstappen", "F. Alonso", "K. Raikkonen", "V. Bottas", "N. Rosberg", "M. Schumacher", "S. Perez", "D. Ricciardo"])
# which overwrote the entire dataframe with one column (i.e., a data series)
# to fix it, I had to assign the results back to only the desired column and not the whole data frame.

# %%
# More DS custom to change values
# Create a dictionary and use .map
# driver_names = {
#    'hamitlon' : "L. Hamilton", 
#    'vettel' : "S. Vettel", etc

#drivers_ranked_top10["driverRef"] = drivers_ranked_top10["driverRef"].map(driver_names)

# %%
# check driverId info
drivers_ranked.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   points     857 non-null    float64
#  1   name full  857 non-null    str
# dtypes: float64(1), str(1)
# memory usage: 13.5 KB

# %%
drivers_ranked
# Out:
#      points         name full
# 0    4540.5    Lewis Hamilton
# 1    3098.0  Sebastian Vettel
# 2    2275.5    Max Verstappen
# 3    2203.0   Fernando Alonso
# 4    1873.0    Kimi Räikkönen
# ..      ...               ...
# 852     0.0        Lloyd Ruby
# 853     0.0        Peter Ryan
# 854     0.0      Menato Boffa
# 855     0.0    Alfonso Thiele
# 856     0.0    Logan Sargeant
#
# [857 rows x 2 columns]

# %%
# create top 10
top10_df = drivers_ranked.sort_values("points", ascending = False).head(10)

# sort values
top10_df = top10_df.sort_values("points", ascending = True)

top10_df.plot.barh("name full", figsize=(10,6), ylabel = "Driver Name", xlabel = "Total Career Points", title = "Top 10 Drivers by Total Career Points", legend= False)
# Out:
# <Axes: title={'center': 'Top 10 Drivers by Total Career Points'}, xlabel='Total Career Points', ylabel='Driver Name'>

# %% [markdown]
# **Day 2:**
# Which constructors have the most wins since 2010?

# %%
# load constructors.csv
constructors_df = pd.read_csv("data/constructors.csv")

# %%
# inspect head of constructors_df
constructors_df.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
# inspect info of constructors_df
constructors_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   constructorId   211 non-null    int64
#  1   constructorRef  211 non-null    str
#  2   name            211 non-null    str
#  3   nationality     211 non-null    str
#  4   url             211 non-null    str
# dtypes: int64(1), str(4)
# memory usage: 8.4 KB

# %%
# check unique constructors
constructors_df["constructorId"].value_counts()
# each constructor only once
# Out:
# constructorId
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 209    1
# 210    1
# 211    1
# 213    1
# 214    1
# Name: count, Length: 211, dtype: int64

# %%
# inspect results_df again
results_df.head(50)
# Out:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 0          1      18         1              1     22     1        1
# 1          2      18         2              2      3     5        2
# 2          3      18         3              3      7     7        3
# 3          4      18         4              4      5    11        4
# 4          5      18         5              1     23     3        5
# 5          6      18         6              3      8    13        6
# 6          7      18         7              5     14    17        7
# 7          8      18         8              6      1    15        8
# 8          9      18         9              2      4     2       \N
# 9         10      18        10              7     12    18       \N
# 10        11      18        11              8     18    19       \N
# 11        12      18        12              4      6    20       \N
# 12        13      18        13              6      2     4       \N
# ...

# %%
# inspect results_df info
results_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26080 entries, 0 to 26079
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26080 non-null  int64
#  1   raceId           26080 non-null  int64
#  2   driverId         26080 non-null  int64
#  3   constructorId    26080 non-null  int64
#  4   number           26080 non-null  str
#  5   grid             26080 non-null  int64
#  6   position         26080 non-null  str
#  7   positionText     26080 non-null  str
#  8   positionOrder    26080 non-null  int64
#  9   points           26080 non-null  float64
#  10  laps             26080 non-null  int64
#  11  time             26080 non-null  str
#  12  milliseconds     26080 non-null  str
#  13  fastestLap       26080 non-null  str
#  14  rank             26080 non-null  str
#  15  fastestLapTime   26080 non-null  str
#  16  fastestLapSpeed  26080 non-null  str
# ...

# %%
# check unique years 
results_df["raceId"].value_counts()
# makes sense to have race id mutliple times as I have a result for each driver
# Out:
# raceId
# 800    55
# 809    47
# 357    39
# 359    39
# 360    39
#        ..
# 668    14
# 837    14
# 660    13
# 827    13
# 765    10
# Name: count, Length: 1091, dtype: int64

# %%
# merge constructors_df with results_df
constructxresults_df = constructors_df.merge(results_df,how = "left", on= "constructorId", validate = "1:m", indicator = True, suffixes = ("_con", "_res"))

# %%
# inspect constructxresults_df
constructxresults_df.head()
# Out:
#    constructorId constructorRef     name nationality  \
# 0              1        mclaren  McLaren     British
# 1              1        mclaren  McLaren     British
# 2              1        mclaren  McLaren     British
# 3              1        mclaren  McLaren     British
# 4              1        mclaren  McLaren     British
#
#                                     url  resultId  raceId  driverId number  \
# 0  http://en.wikipedia.org/wiki/McLaren       1.0    18.0       1.0     22
# 1  http://en.wikipedia.org/wiki/McLaren       5.0    18.0       5.0     23
# 2  http://en.wikipedia.org/wiki/McLaren      25.0    19.0       5.0     23
# 3  http://en.wikipedia.org/wiki/McLaren      27.0    19.0       1.0     22
# 4  http://en.wikipedia.org/wiki/McLaren      49.0    20.0       5.0     23
#
#    grid  ... points  laps         time  milliseconds  fastestLap rank  \
# 0   1.0  ...   10.0  58.0  1:34:50.616       5690616          39    2
# ...

# %%
# check merge
print(constructxresults_df["_merge"].value_counts())
# Out:
# _merge
# both          26080
# left_only         1
# right_only        0
# Name: count, dtype: int64

# %%
# drop columns not needed
constructxresults_df = constructxresults_df.drop(columns = ["url", "resultId", "driverId", "grid", "positionText", "statusId", "fastestLapSpeed", "fastestLapTime", "rank", "fastestLap", "milliseconds","time", "laps" ])

# %%
# inspect constructxresults_df after dropping
constructxresults_df.head()
# Out:
#    constructorId constructorRef     name nationality  raceId number position  \
# 0              1        mclaren  McLaren     British    18.0     22        1
# 1              1        mclaren  McLaren     British    18.0     23        5
# 2              1        mclaren  McLaren     British    19.0     23        3
# 3              1        mclaren  McLaren     British    19.0     22        5
# 4              1        mclaren  McLaren     British    20.0     23        5
#
#    positionOrder  points _merge
# 0            1.0    10.0   both
# 1            5.0     4.0   both
# 2            3.0     6.0   both
# 3            5.0     4.0   both
# 4            5.0     4.0   both

# %%
# check constructxresults_df
constructxresults_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26081 entries, 0 to 26080
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   constructorId   26081 non-null  int64
#  1   constructorRef  26081 non-null  str
#  2   name            26081 non-null  str
#  3   nationality     26081 non-null  str
#  4   raceId          26080 non-null  float64
#  5   number          26080 non-null  str
#  6   position        26080 non-null  str
#  7   positionOrder   26080 non-null  float64
#  8   points          26080 non-null  float64
#  9   _merge          26081 non-null  category
# dtypes: category(1), float64(3), int64(1), str(5)
# memory usage: 1.8 MB

# %%
# .drop() - two ways to drop columns:
#
# Option 1 - columns= (preferred, explicit):
# df.drop(columns=['driverId'])
#
# Option 2 - labels= with axis (generic):
# df.drop(labels='driverId', axis=1)  # axis=1 = columns
# df.drop(labels=0, axis=0)           # axis=0 = rows
#
# To drop a specific row by index:
# df.drop(labels=4, axis=0)  # drops row 4
# df.drop(4)                 # shorthand, same result
#
# axis=0 = rows (goes down)
# axis=1 = columns (goes across)
#
# Rule: always use columns= when dropping columns.
# Only use labels= when dropping rows by index.

# %%
# check races_df again 
races_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   raceId       1101 non-null   int64
#  1   year         1101 non-null   int64
#  2   round        1101 non-null   int64
#  3   circuitId    1101 non-null   int64
#  4   name         1101 non-null   str
#  5   date         1101 non-null   str
#  6   time         1101 non-null   str
#  7   url          1101 non-null   str
#  8   fp1_date     1101 non-null   str
#  9   fp1_time     1101 non-null   str
#  10  fp2_date     1101 non-null   str
#  11  fp2_time     1101 non-null   str
#  12  fp3_date     1101 non-null   str
#  13  fp3_time     1101 non-null   str
#  14  quali_date   1101 non-null   str
#  15  quali_time   1101 non-null   str
#  16  sprint_date  1101 non-null   str
#  17  sprint_time  1101 non-null   str
# dtypes: int64(4), str(14)
# memory usage: 155.0 KB

# %%
# now merge constructxresults_df with races_df
con_res_race_df = constructxresults_df.merge(races_df[["raceId", "year"]], validate = "m:1", indicator = "_merge_2",  on= "raceId", how = "left", suffixes = ("_con_res", "_race" ))

# %%
# Merging with only specific columns from another dataframe:
#
# df1.merge(df2[['key_col', 'wanted_col']], on='key_col', how='inner')
#
# Always include the key column (the one you're joining on)
# plus any other columns you want to bring in.
#
# Why double brackets [[]]?
# Single brackets df['col'] returns a Series (one column, no longer a dataframe)
# Double brackets df[['col']] returns a DataFrame (keeps table structure)
# You need a DataFrame going into merge, not a Series.
#
# Example:
# results_df.merge(drivers_df[['driverId', 'driverRef']], on='driverId', how='inner')

# %%
# inspect con_res_race_df
con_res_race_df.head()
# Out:
#    constructorId constructorRef     name nationality  raceId number position  \
# 0              1        mclaren  McLaren     British    18.0     22        1
# 1              1        mclaren  McLaren     British    18.0     23        5
# 2              1        mclaren  McLaren     British    19.0     23        3
# 3              1        mclaren  McLaren     British    19.0     22        5
# 4              1        mclaren  McLaren     British    20.0     23        5
#
#    positionOrder  points _merge    year _merge_2
# 0            1.0    10.0   both  2008.0     both
# 1            5.0     4.0   both  2008.0     both
# 2            3.0     6.0   both  2008.0     both
# 3            5.0     4.0   both  2008.0     both
# 4            5.0     4.0   both  2008.0     both

# %%
# check merge
con_res_race_df["_merge_2"].value_counts()
# Out:
# _merge_2
# both          26080
# left_only         1
# right_only        0
# Name: count, dtype: int64

# %%
# filter for only races since 2010 and position 1
con_res_race_2010_df = con_res_race_df[(con_res_race_df["year"] >=2010) & (con_res_race_df["position"] == "1")]

# %%
# Filtering rows in a dataframe:
#
# WRONG - this returns True/False for each row, not the filtered dataframe:
# df["year"] >= 2010
#
# CORRECT - wrap it in outer brackets to actually filter:
# df[df["year"] >= 2010]
#
# The outer brackets say "give me all rows where this condition is True"
#
# Multiple conditions:
# df[(df["year"] >= 2010) & (df["position"] == 1)]  # AND
# df[(df["year"] >= 2010) | (df["position"] == 1)]  # OR
#
# Note: use & and | not 'and' and 'or' in pandas filters
# Each condition must be wrapped in its own brackets ()

# %%
# inspect con_res_race_2010_df
con_res_race_2010_df.head()
# Out:
#       constructorId constructorRef     name nationality  raceId number  \
# 1315              1        mclaren  McLaren     British   338.0      1
# 1319              1        mclaren  McLaren     British   340.0      1
# 1325              1        mclaren  McLaren     British   343.0      2
# 1327              1        mclaren  McLaren     British   344.0      2
# 1337              1        mclaren  McLaren     British   349.0      2
#
#      position  positionOrder  points _merge    year _merge_2
# 1315        1            1.0    25.0   both  2010.0     both
# 1319        1            1.0    25.0   both  2010.0     both
# 1325        1            1.0    25.0   both  2010.0     both
# 1327        1            1.0    25.0   both  2010.0     both
# 1337        1            1.0    25.0   both  2010.0     both

# %%
# group by constructors x points
best_construct_since2010_df = con_res_race_2010_df.groupby(["constructorId", "name"])["points"].sum().sort_values(ascending=False).reset_index()

# %%
# Groupby multiple columns to preserve name columns:
#
# INEFFICIENT - groupby ID, then merge names back in:
# df.groupby("constructorId")["points"].sum()
# ...then merge constructors_df to get names again
#
# EFFICIENT - include the name column in groupby directly:
# df.groupby(["constructorId", "constructorRef"])["points"].sum()
#
# Both columns are preserved in the output, no extra merge needed.
#
# Rule: if the name column is already in your dataframe,
# include it in groupby instead of merging it back in afterwards.

# %%
# reset_index() - what it does and when to use it:
#
# After groupby().sum(), the groupby column becomes the index (row label)
# instead of a regular column. This makes it hard to use afterwards.
#
# Without reset_index():
# constructorId         <- this is the index, not a column
#     1          4540.5
#     2          3098.0
#
# With reset_index():
#    constructorId  points   <- constructorId is now a regular column
# 0              1  4540.5
# 1              2  3098.0
#
# Rule: always add reset_index() after groupby() if you need to 
# merge on the grouped column or use it in further operations.^

# %%
# inspect best_construct_since2010_df 
best_construct_since2010_df.head()
# Out:
#    constructorId      name  points
# 0            131  Mercedes  2938.0
# 1              9  Red Bull  2451.5
# 2              6   Ferrari   802.0
# 3              1   McLaren   476.0
# 4            208  Lotus F1    50.0

# %%
# sort it again
best_construct_since2010_df = best_construct_since2010_df.sort_values("points", ascending = True)

best_construct_since2010_df = best_construct_since2010_df.drop(columns = ["constructorId"])

# graph it
best_construct_since2010_df.plot.barh("name", ylabel = "Constructor", xlabel = "Total Points", title = "Best Constructors since 2010", legend= False, figsize = (10,6))
# Out:
# <Axes: title={'center': 'Best Constructors since 2010'}, xlabel='Total Points', ylabel='Constructor'>

# %%
# LESSON: plotting barh cleanly
#
# two ways to set row labels on a horizontal bar chart:
#
# option 1 — pass column name directly (cleaner, recommended)
#   df.drop(columns="unwanted_col").plot.barh("name_col", ...)
#
# option 2 — set_index first
#   df.set_index("name_col")["points"].plot.barh(...)
#   must select column explicitly — otherwise ALL numeric
#   columns get plotted
#
# KEY RULE:
#   barh() plots EVERY numeric column it finds
#   always drop columns you do not want plotted before calling it
#   id columns (driverId, constructorId) are integers → they WILL plot
#   even if the bar is invisible (values too small relative to scale)
#
# to confirm a bar is there but just tiny → use xlim:
#   df.plot.barh("name_col", xlim=(0, 10), ...)
#
# LESSON: set_index
#
# set_index("col") → makes that column the row labels (index)
# the column disappears from the df and becomes the index
#
#   before:                        after:
#   (index)  driverId  name        (index)    name
#   0        1         Hamilton    1          Hamilton
#   1        2         Vettel      2          Vettel
#
# to assign fully custom labels:
#   df.index = ["Driver 1", "Driver 2", "Driver 3"]
#   must supply exactly as many labels as there are rows

# %%
best_construct_since2010.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 best_construct_since2010.head()
#
# NameError: name 'best_construct_since2010' is not defined

# %%
# created above variable by accident, now want to delete it

# DELETING A VARIABLE OR DATAFRAME
#
# del variable_name
#
# removes it from memory completely
# if you try to use it after → NameError
#
# useful when:
#   - you have a large df you no longer need and want to free up memory
#   - you want to clean up intermediate variables in your notebook

# %%
del best_construct_since2010
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 del best_construct_since2010
#
# NameError: name 'best_construct_since2010' is not defined

# %% [markdown]
# Day 3: How have pit stop durations changed over the years?

# %%
# load pit_stops.csv
pit_df = pd.read_csv("data/pit_stops.csv")

# %%
# check info and head
pit_df.info()
pit_df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10089 entries, 0 to 10088
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   raceId        10089 non-null  int64
#  1   driverId      10089 non-null  int64
#  2   stop          10089 non-null  int64
#  3   lap           10089 non-null  int64
#  4   time          10089 non-null  str
#  5   duration      10089 non-null  str
#  6   milliseconds  10089 non-null  int64
# dtypes: int64(5), str(2)
# memory usage: 551.9 KB
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
# check missingness 
pit_df["duration"].isnull().sum()
# Out:
# np.int64(0)

# %%
# how many values contrain ":" in column duration
pit_df.duration.str.contains(":").sum()
# Out:
# np.int64(408)

# %%
# drop rows that contain this string ":"
pit_df = pit_df[pit_df["duration"].str.contains(":") == False]

# %%
pit_df.duration.str.contains(":").sum()
# Out:
# np.int64(0)

# %%
# convert duration into float
pit_df["duration"] = pit_df["duration"].astype("float")

# %%
pit_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9681 entries, 0 to 10088
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   raceId        9681 non-null   int64
#  1   driverId      9681 non-null   int64
#  2   stop          9681 non-null   int64
#  3   lap           9681 non-null   int64
#  4   time          9681 non-null   str
#  5   duration      9681 non-null   float64
#  6   milliseconds  9681 non-null   int64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 605.1 KB

# %%
pit_df["raceId"].count()
# Out:
# np.int64(9681)

# %%
# check races_df
races_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   raceId       1101 non-null   int64
#  1   year         1101 non-null   int64
#  2   round        1101 non-null   int64
#  3   circuitId    1101 non-null   int64
#  4   name         1101 non-null   str
#  5   date         1101 non-null   str
#  6   time         1101 non-null   str
#  7   url          1101 non-null   str
#  8   fp1_date     1101 non-null   str
#  9   fp1_time     1101 non-null   str
#  10  fp2_date     1101 non-null   str
#  11  fp2_time     1101 non-null   str
#  12  fp3_date     1101 non-null   str
#  13  fp3_time     1101 non-null   str
#  14  quali_date   1101 non-null   str
#  15  quali_time   1101 non-null   str
#  16  sprint_date  1101 non-null   str
#  17  sprint_time  1101 non-null   str
# dtypes: int64(4), str(14)
# memory usage: 155.0 KB

# %%
# check head of races_df
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
races_df["raceId"].count()
# Out:
# np.int64(1101)

# %%
# merge pit_df with races_df
race_pit_df = pit_df.merge(races_df[["raceId", "year"]], how = "left", validate = "m:1", indicator = True, on= "raceId")

# %%
# inspect race_pit_df
race_pit_df.head()
# Out:
#    raceId  driverId  stop  lap      time  duration  milliseconds  year _merge
# 0     841       153     1    1  17:05:23    26.898         26898  2011   both
# 1     841        30     1    1  17:05:52    25.021         25021  2011   both
# 2     841        17     1   11  17:20:48    23.426         23426  2011   both
# 3     841         4     1   12  17:22:34    23.251         23251  2011   both
# 4     841        13     1   13  17:24:10    23.842         23842  2011   both

# %%
# inspect to see if merge worked correctly
race_pit_df["_merge"].value_counts()
# Out:
# _merge
# both          9681
# left_only        0
# right_only       0
# Name: count, dtype: int64

# %%
# drop "_merge"
race_pit_df = race_pit_df.drop(columns="_merge")

# %%
# check that drop worked
race_pit_df.head()
# Out:
#    raceId  driverId  stop  lap      time  duration  milliseconds  year
# 0     841       153     1    1  17:05:23    26.898         26898  2011
# 1     841        30     1    1  17:05:52    25.021         25021  2011
# 2     841        17     1   11  17:20:48    23.426         23426  2011
# 3     841         4     1   12  17:22:34    23.251         23251  2011
# 4     841        13     1   13  17:24:10    23.842         23842  2011

# %%
avg_pittime_by_year_df = race_pit_df.groupby("year")["duration"].mean().reset_index()

# %%
# inspect head of avg_pittime_by_year
avg_pittime_by_year_df.head()
# Out:
#    year   duration
# 0  2011  23.568104
# 1  2012  23.283770
# 2  2013  23.560905
# 3  2014  24.962164
# 4  2015  25.273400

# %%
avg_pittime_by_year_df["duration"] = avg_pittime_by_year_df["duration"].round(2)

# %%
# plot as line chart
avg_pittime_by_year_df.plot.line("year", figsize=(10,6), title = "Average Pit Stop Duration Per Year", xlabel = "Year", ylabel = "Duration (in seconds)", legend = False, color = "red")
# Out:
# <Axes: title={'center': 'Average Pit Stop Duration Per Year'}, xlabel='Year', ylabel='Duration (in seconds)'>

# %% [markdown]
# Which constructors had the fastest average pit duration in 2016?

# %%
# inspect race_pit_df again
race_pit_df.head()
# Out:
#    raceId  driverId  stop  lap      time  duration  milliseconds  year
# 0     841       153     1    1  17:05:23    26.898         26898  2011
# 1     841        30     1    1  17:05:52    25.021         25021  2011
# 2     841        17     1   11  17:20:48    23.426         23426  2011
# 3     841         4     1   12  17:22:34    23.251         23251  2011
# 4     841        13     1   13  17:24:10    23.842         23842  2011

# %%
# inspect constructors_df
constructors_df.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
# inspect results_df
results_df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26075     26081    1110       817            213      3    19       16
# 26076     26082    1110       858              3      2    18       17
# 26077     26083    1110       807            210     27     0       18
# 26078     26084    1110       832              6     55     4       \N
# 26079     26085    1110       857              1     81     5       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
results_df["driverId"].count()
# Out:
# np.int64(26080)

# %%
race_pit_df["driverId"].count()
# Out:
# np.int64(9681)

# %%
# merge race_pit_df with results_df
race_pit_cons_df = race_pit_df.merge(results_df[["driverId", "raceId", "constructorId"]], on = ["driverId", "raceId"], how = "left", validate = "m:m", indicator = True)

# %%
race_pit_cons_df.head()
# Out:
#    raceId  driverId  stop  lap      time  duration  milliseconds  year  \
# 0     841       153     1    1  17:05:23    26.898         26898  2011
# 1     841        30     1    1  17:05:52    25.021         25021  2011
# 2     841        17     1   11  17:20:48    23.426         23426  2011
# 3     841         4     1   12  17:22:34    23.251         23251  2011
# 4     841        13     1   13  17:24:10    23.842         23842  2011
#
#    constructorId _merge
# 0              5   both
# 1            131   both
# 2              9   both
# 3              6   both
# 4              6   both

# %%
race_pit_cons_df["_merge"].value_counts()
# Out:
# _merge
# both          9681
# left_only        0
# right_only       0
# Name: count, dtype: int64

# %%
race_pit_cons_df = race_pit_cons_df.drop(columns = "_merge")

# %%
race_pit_cons_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9681 entries, 0 to 9680
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   raceId         9681 non-null   int64
#  1   driverId       9681 non-null   int64
#  2   stop           9681 non-null   int64
#  3   lap            9681 non-null   int64
#  4   time           9681 non-null   str
#  5   duration       9681 non-null   float64
#  6   milliseconds   9681 non-null   int64
#  7   year           9681 non-null   int64
#  8   constructorId  9681 non-null   int64
# dtypes: float64(1), int64(7), str(1)
# memory usage: 680.8 KB

# %%
constructors_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   constructorId   211 non-null    int64
#  1   constructorRef  211 non-null    str
#  2   name            211 non-null    str
#  3   nationality     211 non-null    str
#  4   url             211 non-null    str
# dtypes: int64(1), str(4)
# memory usage: 8.4 KB

# %%
race_pit_cons_df.head()
# Out:
#    raceId  driverId  stop  lap      time  duration  milliseconds  year  \
# 0     841       153     1    1  17:05:23    26.898         26898  2011
# 1     841        30     1    1  17:05:52    25.021         25021  2011
# 2     841        17     1   11  17:20:48    23.426         23426  2011
# 3     841         4     1   12  17:22:34    23.251         23251  2011
# 4     841        13     1   13  17:24:10    23.842         23842  2011
#
#    constructorId
# 0              5
# 1            131
# 2              9
# 3              6
# 4              6

# %%
race_pit_cons_df = race_pit_cons_df.merge(constructors_df[["constructorId", "name"]], on = "constructorId", validate= "m:1", how = "left", indicator = "_merge2")

# %%
race_pit_cons_df = race_pit_cons_df.drop(columns = ["_merge", "_merge2"])

# %%
race_pit_cons_df = race_pit_cons_df.drop(columns = "name_x")

# %%
race_pit_cons_df = race_pit_cons_df.rename(columns= {"name_y" : "name_cons"})

# %%
race_pit_cons_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9870 entries, 0 to 9869
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   raceId         9681 non-null   float64
#  1   driverId       9681 non-null   float64
#  2   stop           9681 non-null   float64
#  3   lap            9681 non-null   float64
#  4   time           9681 non-null   str
#  5   duration       9681 non-null   float64
#  6   milliseconds   9681 non-null   float64
#  7   year           9681 non-null   float64
#  8   constructorId  9870 non-null   int64
#  9   name_cons      9870 non-null   str
# dtypes: float64(7), int64(1), str(2)
# memory usage: 771.2 KB

# %%
champ_2016 = race_pit_cons_df[race_pit_cons_df["year"] == 2016]

# %%
champ_2016.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 912 entries, 421 to 8920
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   raceId         912 non-null    float64
#  1   driverId       912 non-null    float64
#  2   stop           912 non-null    float64
#  3   lap            912 non-null    float64
#  4   time           912 non-null    str
#  5   duration       912 non-null    float64
#  6   milliseconds   912 non-null    float64
#  7   year           912 non-null    float64
#  8   constructorId  912 non-null    int64
#  9   name_cons      912 non-null    str
# dtypes: float64(7), int64(1), str(2)
# memory usage: 78.4 KB

# %%
con_pitdur_2016 = champ_2016.groupby(["constructorId", "name_cons"])["duration"].mean().round(2).reset_index()

# %%
con_pitdur_2016.head()
# Out:
#    constructorId   name_cons  duration
# 0              1     McLaren     23.97
# 1              3    Williams     24.08
# 2              4     Renault     24.96
# 3              5  Toro Rosso     25.07
# 4              6     Ferrari     23.90

# %%
top5_con_pitdur_2016 = con_pitdur_2016.sort_values("duration", ascending = True).head(5)

top5_con_pitdur_2016.head()

top_5 = top5_con_pitdur_2016.drop(columns = "constructorId")

# %%
top_5
# Out:
#      name_cons  duration
# 8     Mercedes     23.75
# 4      Ferrari     23.90
# 0      McLaren     23.97
# 6  Force India     24.00
# 1     Williams     24.08

# %%
top_5.plot.barh("name_cons", ylabel = "Constructor", xlabel = "Time (in milliseconds)", title = "Top 5 Average Pit Duration by Constructors", figsize = (10,6), legend = False )
# Out:
# <Axes: title={'center': 'Top 5 Average Pit Duration by Constructors'}, xlabel='Time (in milliseconds)', ylabel='Constructor'>
